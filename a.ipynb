# %%
1
# Out:
# 1

# %%
import pandas as pd

# %%
data = pd.read_excel("project2_delivery_data.xlsx")
data
# Out:
#      Distance_km  Item_Count  Traffic_Level  Active_Courier_Orders  \
# 0            8.7           9             10                      6
# 1            2.0          11             10                     10
# 2            6.1          15              1                      7
# 3            3.6          14              9                      0
# 4            6.1          10              2                     19
# ..           ...         ...            ...                    ...
# 995          0.7          10              5                      5
# 996          6.8          15              9                      4
# 997         13.2           7              9                     13
# 998          4.6          14              3                      0
# 999          2.5          10              6                      1
#
#      Delivery_Time_min
# 0                 66.3
# 1                 55.5
# 2                 46.8
# 3                 49.4
# 4                 46.9
# ...

# %%
data.columns
# Out:
# Index(['Distance_km', 'Item_Count', 'Traffic_Level', 'Active_Courier_Orders',
#        'Delivery_Time_min'],
#       dtype='str')

# %%
x=data[['Distance_km', 'Item_Count', 'Traffic_Level', 'Active_Courier_Orders']]
y=data['Delivery_Time_min']
y
# Out:
# 0      66.3
# 1      55.5
# 2      46.8
# 3      49.4
# 4      46.9
#        ...
# 995    29.7
# 996    52.6
# 997    77.9
# 998    35.0
# 999    44.8
# Name: Delivery_Time_min, Length: 1000, dtype: float64

# %%
x=data[['screen_brightness', 'internet_usage_min', 'gaming_usage_min']]
y=data['battery_hours']
y
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 x=data[['screen_brightness', 'internet_usage_min', 'gaming_usage_min']]
#       2 y=data['battery_hours']
#       3 y
#
# File c:\Users\Bashir-Rayaneh\Desktop\cat_dog\cool\Lib\site-packages\pandas\core\frame.py:4384, in DataFrame.__getitem__(self, key)
#    4380                 indexer = [indexer]
#    4381         else:
#    4382             if is_iterator(key):
#    4383                 key = list(key)
# -> 4384             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4385
#    4386         # take() does not accept boolean indexers
#    4387         if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\Bashir-Rayaneh\Desktop\cat_dog\cool\Lib\site-packages\pandas\core\indexes\base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#    6299 else:
# ...

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

# %%
from sklearn.model_selection import train_test_split

x_test,x_train,y_test,y_train=train_test_split(x,y,test_size=0.3)

# %%
x_test
# Out:
#      Distance_km  Item_Count  Traffic_Level  Active_Courier_Orders
# 390         15.6          14              9                      1
# 219          7.1           8              1                      0
# 583          9.5          13              7                      0
# 597         10.3          11              6                      7
# 756         11.6           3              6                     13
# ..           ...         ...            ...                    ...
# 532          7.1           3              8                     11
# 547          1.8          15             10                     19
# 639          4.0          10             10                      6
# 670          4.8          11              1                     19
# 57           5.6           9              4                      8
#
# [700 rows x 4 columns]

# %%
y_test
# Out:
# 390    77.4
# 219    26.5
# 583    64.7
# 597    61.5
# 756    65.4
#        ...
# 532    64.7
# 547    56.8
# 639    42.2
# 670    44.5
# 57     46.0
# Name: Delivery_Time_min, Length: 700, dtype: float64

# %%
model = LinearRegression()

model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.predict(np.array([15.6,14.0,9,1.0]).reshape(1,-1))
# Out:
# c:\Users\Bashir-Rayaneh\Desktop\cat_dog\cool\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([76.68303011])

# %%
y_test
# Out:
# 390    77.4
# 219    26.5
# 583    64.7
# 597    61.5
# 756    65.4
#        ...
# 532    64.7
# 547    56.8
# 639    42.2
# 670    44.5
# 57     46.0
# Name: Delivery_Time_min, Length: 700, dtype: float64

# %%
model.predict(x_test)
# Out:
# array([ 76.74584276,  35.70512294,  56.65549667,  61.20978284,
#         64.17196809,  39.43197681,  43.14072241,  57.50285986,
#         23.28141531,  40.54564575,  56.41211621,  73.17610597,
#         25.62931544,  56.2690047 ,  54.18798748,  45.46938895,
#         47.15321727,  56.33850093,  64.51038948,  25.95689499,
#         84.75699408,  84.46129725,  70.49742587,  81.33981751,
#         34.60967923,  36.01518501,  49.84081323,  52.31761432,
#         48.32366767,  60.45580626,  64.89410839,  38.43984779,
#         51.21527849,  69.86161176,  55.58531625,  30.20064144,
#        100.31692587,  67.61980426,  60.40301712,  35.9971232 ,
#         59.9621899 ,  56.06647972,  42.50987829,  52.49086621,
#         57.52898557,  48.34754828,  59.90460395,  51.55322711,
#         51.77390363,  46.83974492,  54.90735858,  36.45157995,
#         36.03526569,  43.69453437,  45.63162582,  54.03285258,
#         89.28969504,  57.87258468,  47.73774677,  50.8396748 ,
# ...

# %%
y_test
# Out:
# 6       6.02
# 119     4.99
# 41     14.95
# 128     3.58
# 190     6.43
#        ...
# 178    12.01
# 140    15.10
# 9       5.33
# 17      6.51
# 67     14.28
# Name: battery_hours, Length: 140, dtype: float64

# %%
t=np.array([1,2,6,8])
p=np.array([1,3,6.8,10])

MAE= np.mean(np.abs(p-t))
MSE= np.mean(np.square(p-t))
RMSE=np.sqrt(np.mean(np.square(p-t)))

MAE,MSE,RMSE
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 t=np.array([1,2,6,8])
#       2 p=np.array([1,3,6.8,10])
#       3
#       4 MAE= np.mean(np.abs(p-t))
#
# NameError: name 'np' is not defined

# %%
# Out:
# int
